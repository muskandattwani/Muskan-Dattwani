# %% [markdown]
# #Data Science Assignment
# #Module 1 Pyhon
# #Name: Muskan Dattwani

# %% [markdown]
# #Q-1 Write a python program to sum of the first n positive integers.

# %%
n = int(input("Input a number: "))
sum = (n*(n+1))/2
print("Sum of the first",n,"positive integers: ",sum)
# Out:
# Input a number: 5
# Sum of the first 5 positive integers:  15.0

# %% [markdown]
# #Q-2 Write a Python program to count occurrences of a substring in a string.

# %%
string = "tops technology"
#number of occurance is 't'
print("number of occurance: ",string.count('t'))
# Out:
# number of occurance:  2

# %% [markdown]
# #Q-3 Write a Python program to count the occurrences of each word in a given sentence.

# %%
def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

print( word_count('the quick brown fox jumps over the lazy dog.'))
# Out:
# {'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog.': 1}

# %% [markdown]
# #Q-4 Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.

# %%
def string (a,b):
  new_a = b[:2] + a[-1]
  new_b = a[:2] + b[-1]

  return new_a + ' ' + new_b
print(string('abc','xyz'))
# Out:
# xyc abz

# %% [markdown]
# #Q-5 Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing' then add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.

# %%
def add_string(str1):
  length = len(str1)

  if length > 2:
    if str1[-3:] == 'ing':
      str1 += 'ly'
    else:
      str1 += 'ing'

    return str1
print(add_string('ab'))
print(add_string('abc'))
print(add_string('string'))
# Out:
# None
# abcing
# stringly

# %%
def add_string(str1):
  length = len(str1)

  if length > 2:
    if str1[-3:] == 'ing':
      str1 += 'ly'
    else:
      str1 += 'ing'

  return str1
print(add_string('ab'))
print(add_string('abc'))
print(add_string('string'))
# Out:
# ab
# abcing
# stringly

# %% [markdown]
# #Q-6 Write a Python program to find the first appearance of the substring 'not' and 'poor' from a given string, if 'not' follows the 'poor', replace the whole 'not'...'poor' substring with 'good'. Return the resulting string.

# %%
def not_poor(str):
  str_not = str.find('not')
  str_poor = str.find('poor')

  if str_poor > str_not and str_not>0 and str_poor>0:
    str = str.replace(str[str_not:(str_poor+4)], 'good')
    return str
  else:
    return str
print(not_poor('The lyrics is not that poor!!'))
print(not_poor('The lyrics is poor!!'))
# Out:
# The lyrics is good!!
# The lyrics is poor!!

# %% [markdown]
# #Q-7 Program to find Greatest Common Divisor of two numbers.
# #For example, the GCD of 20 and 28 is 4 and GCD of 98 and 56 is 14.

# %%
import math
print("The gcd of 20 and 28 is : ",end="")
print(math.gcd(20,48))
# Out:
# The gcd of 20 and 28 is : 4

# %%
#using while loop
num1 = int(input("Enter 1st number: "))
num2 = int(input("Enter 2nd number: "))
i = 1
while(i <= num1 and i <= num2):
  if(num1 % i == 0 and num2 % i == 0):
    gcd = i
  i = i + 1
print("GCD is", gcd)
# Out:
# Enter 1st number: 98
# Enter 2nd number: 56
# GCD is 14

# %%
num1 = 98
num2 = 56
i = 1
while(i <= num1 and i <= num2):
  if(num1 % i == 0 and num2 % i == 0):
    gcd = i
  i = i + 1
print("GCD is", gcd)
# Out:
# GCD is 14

# %% [markdown]
#  # Q-8 Write a Python program to check whether a list contains a sublist.

# %%
def sublist(l, s):
	set = False
	if s == []:
		set = True
	elif s == l:
		set = True
	elif len(s) > len(l):
		set = False

	else:
		for i in range(len(l)):
			if l[i] == s[0]:
				n = 1
				while (n < len(s)) and (l[i+n] == s[n]):
					n += 1
				
				if n == len(s):
					set = True

	return set

a = [2,3,47,9]
b = [4,2]
c = [3,9]
print(sublist(a, b))
print(sublist(a, c))
# Out:
# False
# False

# %% [markdown]
# # Q-9Write a Python program to find the second smallest number in a list.

# %%
def small(no):
  if (len(no)<2):
    return
  if((len)(no)==2) and (no[0] == no[1]):
    return
  a = set()
  b = []
  for x in no:
    if x not in a:
      b.append(x)
      a.add(x)
  b.sort()
  return b[1]


print(small([1, 2, 6, 0, 5]))
print(small([-1, -1, 0, 0, -2, -2, -2]))
print(small([1, 1, 1, 0, 0, 0, 2, -2, -2]))
print(small([26,26]))
print(small([26]))
# Out:
# 1
# -1
# 0
# None
# None

# %% [markdown]
#  # Q-10 Write a Python program to get unique values from a list.

# %%
my_list = [10,20,30,40,50,50,40]
print("Original list",my_list)
set = set(my_list)
new_list = list(set)
print("Unique numbers : ",new_list)
# Out:
# Original list [10, 20, 30, 40, 50, 50, 40]
# Unique numbers :  [40, 10, 50, 20, 30]

# %% [markdown]
# # Q-11 Write a Python program to unzip a list of tuples into individual lists.

# %%
l = [(1,2),(3,4),(5,6)]
print(list(zip(*l)))
# Out:
# [(1, 3, 5), (2, 4, 6)]

# %% [markdown]
# # Q-12 Write a Python program to convert a list of tuples into a dictionary.

# %%
l = [("a",1), ("a",2), ("a",3), ("b",1), ("b",2), ("c",1), ("c",2)]
d = {}
for x, y in l:
  d.setdefault(x, []).append(y)
print(d)
# Out:
# {'a': [1, 2, 3], 'b': [1, 2], 'c': [1, 2]}

# %% [markdown]
#  # Q-13 Write a Python program to sort a dictionary (ascending /descending) by value.

# %%
import operator  
d = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}  
print('Original dictionary : ',d)  
dic = sorted(d.items(), key=operator.itemgetter(0))  
print('Dictionary in ascending order by value : ',dic)  
dic = sorted(d.items(), key=operator.itemgetter(0),reverse=True)  
print('Dictionary in descending order by value : ',dic)
# Out:
# Original dictionary :  {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
# Dictionary in ascending order by value :  [(0, 0), (1, 2), (2, 1), (3, 4), (4, 3)]
# Dictionary in descending order by value :  [(4, 3), (3, 4), (2, 1), (1, 2), (0, 0)]

# %%
d = {5:4, 1:6, 6:3}

dic = {key: value for key, value in sorted(d.items(), key=lambda item: item[1])}

print(dic)
# Out:
# {6: 3, 5: 4, 1: 6}

# %% [markdown]
#  # Q-14 Write a Python program to find the highest 3 values in a dictionary.

# %%
from collections import Counter
dic = {"A": 26, "B": 20, "C": 30, "D": 40}
k = Counter(dic)

highest = k.most_common(3)

print("Initial dictionary: ")
print(dic, "\n")

print("3 highest values of dictionary: ")
print("Keys: Values")

for i in highest:
  print(i[0]," :",i[1]," ")
# Out:
# Initial dictionary:
# {'A': 26, 'B': 20, 'C': 30, 'D': 40}
#
# 3 highest values of dictionary:
# Keys: Values
# D  : 40
# C  : 30
# A  : 26

# %% [markdown]
# # Q-15 Given a number n, write a python program to make and print the list of Fibonacci series up to n.
# # Input : n=7
# # Hint : first 7 numbers in the series
# # Expected output :
# # First few Fibonacci numbers are 0, 1, 1, 2, 3, 5, 8, 13

# %%
n_terms= int(input("how many terms are there?"))

#1st two terms
n1, n2 = 0,1
count = 0

#check the numbers of terms is valid pr not:
if n_terms <= 0:
  print("Please enter a positive number")

elif n_terms == 1:
  print("Fibomacci sequence is upto", n_terms,":")
  print(n1)

else:
  print("Fibonacci sequence: ")

  while count < n_terms:
    print(n1)
    nth = n1 + n2

    n1 = n2
    n2 = nth
    count +=1
# Out:
# how many terms are there?8
# Fibonacci sequence:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %% [markdown]
# # Q-16 Counting the frequencies in a list using a dictionary in Python.
# # Input : [1, 1, 1, 5, 5, 3, 1, 3, 3, 1,4, 4, 4, 2, 2, 2, 2]
# # Expected output : 1 : 5 , 2 : 4 , 3 : 3 , 4 : 3 , 5 : 2

# %%
def l(my_list):

#creating a empty dictionary:
  d = {}
  for items in my_list:
    d[items] = my_list.count(items)

  for key, value in d.items():
    print ("%d : %d"%(key, value))

if __name__ == "__main__":
  my_list = [1, 1, 1, 5, 5, 3, 1, 3, 3, 1,4, 4, 4, 2, 2, 2, 2]
  l(my_list)
# Out:
# 1 : 5
# 5 : 2
# 3 : 3
# 4 : 3
# 2 : 4

# %%
def l(my_list):

#creating a empty dictionary:
  d = {}
  for i  in [1, 1, 1, 5, 5, 3, 1, 3, 3, 1,4, 4, 4, 2, 2, 2, 2]:
    d[i] = d.get(i, 0) + 1
  return d

if __name__ == "__main__":
  my_list = [1, 1, 1, 5, 5, 3, 1, 3, 3, 1,4, 4, 4, 2, 2, 2, 2]
  print (l(my_list))
# Out:
# {1: 5, 5: 2, 3: 3, 4: 3, 2: 4}

# %% [markdown]
# # Q-17 Write a python program using function to find the sum of odd series and even series
# # Odd series: 12/ 1! + 32/ 3! + 52/ 5!+……n
# # Even series: 22/ 2! + 42/ 4! + 62/ 6!+……n

# %% [markdown]
# # Q-18 Python Program to Find Factorial of Number Using Recursion.

# %%
#Factorial of Number Using Recursion from user enter: 
def recursion(a):
  if a == 1:
    return a
  else:
    return a*recursion(a-1)

i = int(input("write a number: "))

if i < 0:
  print("It is a negative number")
elif i == 0:
  print("The factorial of %d is %d")
else:
  print("The factorial of",i,"is", recursion(i))
# Out:
# write a number: 5
# The factorial of 5 is 120

# %%
def recursion(a):
  if a == 1:
    return a
  else:
    return a*recursion(a-1)

i = 5
if i < 0:
  print("It is a negative number")
elif i == 0:
  print("The factorial of %d is %d")
else:
  print("The factorial of",i,"is", recursion(i))
# Out:
# The factorial of 5 is 120

# %% [markdown]
# # Q-19 Write a Python function that takes a list and returns a new list with unique elements of the first list.

# %%
def a(l):
  x = []

  for i in l:
    if i not in x:
      x.append(i)
      return x
  
print(a([1,2,3,3,4,5,6,6,8]))
# Out:
# [1]

# %%
def a(l):
  a = set(l)
  print(sorted(a))
a([1,2,3,3,4,5,6,6,7,8])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# # Q-20 Mini project :
# # Problem Statement : Password Generator
# # Make a program to generate a strong password using the input given by the user. To generate a password, randomly take some words from the user input and then include numbers, special characters and capital letters to generate the password. Also, keep a check that password length is more than 8 characters.
# #Note: Include Exception handling wherever required. Also, make a ‘User’ class and store the details like user id, name and password of each user as a tuple.
